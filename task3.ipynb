# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
dataset=pd.read_csv("C:\\Users\\sejalpatil1728\\Downloads\\bank+marketing\\bank-additional\\bank-additional\\bank-additional.csv")
dataset
# Out:
#       age          job  marital          education default  housing     loan  \
# 0      30  blue-collar  married           basic.9y      no      yes       no
# 1      39     services   single        high.school      no       no       no
# 2      25     services  married        high.school      no      yes       no
# 3      38     services  married           basic.9y      no  unknown  unknown
# 4      47       admin.  married  university.degree      no      yes       no
# ...   ...          ...      ...                ...     ...      ...      ...
# 4114   30       admin.  married           basic.6y      no      yes      yes
# 4115   39       admin.  married        high.school      no      yes       no
# 4116   27      student   single        high.school      no       no       no
# 4117   58       admin.  married        high.school      no       no       no
# 4118   34   management   single        high.school      no      yes       no
#
# ...

# %%
dataset.rename(columns={'y': 'deposit'}, inplace=True)
dataset.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4119 non-null   int64
#  1   job             4119 non-null   object
#  2   marital         4119 non-null   object
#  3   education       4119 non-null   object
#  4   default         4119 non-null   object
#  5   housing         4119 non-null   object
#  6   loan            4119 non-null   object
#  7   contact         4119 non-null   object
#  8   month           4119 non-null   object
#  9   day_of_week     4119 non-null   object
#  10  duration        4119 non-null   int64
#  11  campaign        4119 non-null   int64
#  12  pdays           4119 non-null   int64
#  13  previous        4119 non-null   int64
#  14  poutcome        4119 non-null   object
#  15  emp.var.rate    4119 non-null   float64
#  16  cons.price.idx  4119 non-null   float64
# ...

# %%
dataset.shape
# Out:
# (4119, 21)

# %%
dataset.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'deposit'],
#       dtype='object')

# %%
dataset.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# deposit            object
# dtype: object

# %%
dataset.dtypes.value_counts()
# Out:
# object     11
# int64       5
# float64     5
# Name: count, dtype: int64

# %%
dataset.duplicated().sum()
# Out:
# 0

# %%
dataset.isna().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# deposit           0
# dtype: int64

# %%
cat_cols=dataset.select_dtypes(include='object').columns
print(cat_cols)
num_cols=dataset.select_dtypes(exclude='object').columns
print(num_cols)
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'day_of_week', 'poutcome', 'deposit'],
#       dtype='object')
# Index(['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate',
#        'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed'],
#       dtype='object')

# %%
dataset.describe()
# Out:
#                age     duration     campaign        pdays     previous  \
# count  4119.000000  4119.000000  4119.000000  4119.000000  4119.000000
# mean     40.113620   256.788055     2.537266   960.422190     0.190337
# std      10.313362   254.703736     2.568159   191.922786     0.541788
# min      18.000000     0.000000     1.000000     0.000000     0.000000
# 25%      32.000000   103.000000     1.000000   999.000000     0.000000
# 50%      38.000000   181.000000     2.000000   999.000000     0.000000
# 75%      47.000000   317.000000     3.000000   999.000000     0.000000
# max      88.000000  3643.000000    35.000000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed
# count   4119.000000     4119.000000    4119.000000  4119.000000  4119.000000
# mean       0.084972       93.579704     -40.499102     3.621356  5166.481695
# std        1.563114        0.579349       4.594578     1.733591    73.667904
# ...

# %%
dataset.describe(include='object')
# Out:
#            job  marital          education default housing  loan   contact  \
# count     4119     4119               4119    4119    4119  4119      4119
# unique      12        4                  8       3       3     3         2
# top     admin.  married  university.degree      no     yes    no  cellular
# freq      1012     2509               1264    3315    2175  3349      2652
#
#        month day_of_week     poutcome deposit
# count   4119        4119         4119    4119
# unique    10           5            3       2
# top      may         thu  nonexistent      no
# freq    1378         860         3523    3668

# %%
dataset.hist(figsize=(10,10),color='#000080')
plt.show()

# %%
for feature in cat_cols:
    plt.figure(figsize=(5,5))
    sns.countplot(x=feature, data=dataset, palette='pastel')
    plt.title(f'Bar plot of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Count')
    plt.xticks(rotation=90)  # Corrected this line
    plt.show()

# %%
dataset.plot(kind='box', subplots=True, layout=(2, 5), figsize=(20, 10), color='#000080')
plt.show()

# %%
column=dataset[['age','campaign','duration']]
q1=np.percentile(column,25)
q3=np.percentile(column,75)
iqr=q3-q1
lower_bound=q1-1.5*iqr
upper_bound=q3+1.5*iqr
dataset[['age','campaign','duration']]=column[(column>lower_bound)&(column<upper_bound)]

# %%
dataset.plot(kind='box', subplots=True, layout=(2, 5), figsize=(20, 10), color='#000080')
plt.show()

# %%
numeric_dataset = dataset.select_dtypes(include=['number'])
corr = numeric_dataset.corr()
print(corr)
filtered_corr = corr[(abs(corr) >= 0.90) ]
plt.figure(figsize=(10, 8))
sns.heatmap(filtered_corr, annot=True, cmap='Set3', linewidths=0.2)
plt.show()
# Out:
#                      age  duration  campaign     pdays  previous  \
# age             1.000000  0.014048 -0.014169 -0.043425  0.050931
# duration        0.014048  1.000000 -0.218111 -0.093694  0.094206
# campaign       -0.014169 -0.218111  1.000000  0.058742 -0.091490
# pdays          -0.043425 -0.093694  0.058742  1.000000 -0.587941
# previous        0.050931  0.094206 -0.091490 -0.587941  1.000000
# emp.var.rate   -0.019192 -0.063870  0.176079  0.270684 -0.415238
# cons.price.idx -0.000482 -0.013338  0.145021  0.058472 -0.164922
# cons.conf.idx   0.098135  0.045889  0.007882 -0.092090 -0.051420
# euribor3m      -0.015033 -0.067815  0.159435  0.301478 -0.458851
# nr.employed    -0.041936 -0.097339  0.161037  0.381983 -0.514853
#
#                 emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# age                -0.019192       -0.000482       0.098135  -0.015033
# duration           -0.063870       -0.013338       0.045889  -0.067815
# ...

# %%
hight_corr_cols={'emp.var.rate','euribor3m','nr.employed'}

# %%
Dataset1=dataset.copy()
Dataset1.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'deposit'],
#       dtype='object')

# %%
Dataset1.drop(hight_corr_cols,inplace=True,axis=1)
Dataset1.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'cons.price.idx', 'cons.conf.idx', 'deposit'],
#       dtype='object')

# %%
Dataset1.shape
# Out:
# (4119, 18)

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df_encoded=Dataset1.apply(lb.fit_transform)
df_encoded
# Out:
#       age  job  marital  education  default  housing  loan  contact  month  \
# 0      12    1        1          2        0        2     0        0      6
# 1      21    7        2          3        0        0     0        1      6
# 2       7    7        1          3        0        2     0        1      4
# 3      20    7        1          2        0        1     1        1      4
# 4      29    0        1          6        0        2     0        0      7
# ...   ...  ...      ...        ...      ...      ...   ...      ...    ...
# 4114   12    0        1          1        0        2     2        0      3
# 4115   21    0        1          3        0        2     0        1      3
# 4116    9    8        2          3        0        0     0        0      6
# 4117   40    0        1          3        0        0     0        0      1
# 4118   16    4        2          3        0        2     0        0      7
#
#       day_of_week  duration  campaign  pdays  previous  poutcome  \
# ...

# %%
df_encoded['deposit'].value_counts()
# Out:
# deposit
# 0    3668
# 1     451
# Name: count, dtype: int64

# %%
x= df_encoded.drop('deposit',axis=1)
y= df_encoded['deposit']
print(x.shape)
print(y.shape)
print(type(x))
print(type(y))
# Out:
# (4119, 17)
# (4119,)
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
from sklearn.model_selection import train_test_split
print(4119*0.25)
# Out:
# 1029.75

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3089, 17)
# (1030, 17)
# (3089,)
# (1030,)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
def eval_model(y_test, y_pred):
    # Calculate accuracy
    acc = accuracy_score(y_test, y_pred)
    print('Accuracy Score:', acc)
    # Compute confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    print('Confusion Matrix\n', cm)
    # Print classification report
    print('Classification Report\n', classification_report(y_test, y_pred))

def escore(model):
    train_score = model.score(x_train,y_train)
    test_score = model.score(x_test,y_test)
    print("Training Score", train_score)
    print('Testing Score',test_score)

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(criterion='gini', max_depth=5, min_samples_split=18)
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_split=18)

# %%
escore(dt)
# Out:
# Training Score 0.9125930721916478
# Testing Score 0.8961165048543689

# %%
ypred_dt = dt.predict(x_test)
print(ypred_dt)
# Out:
# [0 0 0 ... 0 0 0]

# %%
eval_model(y_test,ypred_dt)
# Out:
# Accuracy Score: 0.8961165048543689
# Confusion Matrix
#  [[905  25]
#  [ 82  18]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94       930
#            1       0.42      0.18      0.25       100
#
#     accuracy                           0.90      1030
#    macro avg       0.67      0.58      0.60      1030
# weighted avg       0.87      0.90      0.88      1030

# %%
from sklearn.tree import plot_tree

# %%
cn = ['no','yes']
fn=x_train.columns
print(fn)
print(cn)
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'cons.price.idx', 'cons.conf.idx'],
#       dtype='object')
# ['no', 'yes']

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
plt.figure(figsize=(20, 10)) 
plot_tree(dt, class_names=cn, filled=True)
plt.show()

# %%
dt1 = DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_split=18)
dt1.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_split=18)

# %%
escore(dt1)
# Out:
# Training Score 0.9119456134671414
# Testing Score 0.9116504854368932

# %%
ypred_dt1 = dt1.predict(x_test)
print(ypred_dt1)
# Out:
# [0 0 1 ... 0 0 0]

# %%
eval_model(y_test,ypred_dt1)
# Out:
# Accuracy Score: 0.9116504854368932
# Confusion Matrix
#  [[921   9]
#  [ 82  18]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95       930
#            1       0.67      0.18      0.28       100
#
#     accuracy                           0.91      1030
#    macro avg       0.79      0.59      0.62      1030
# weighted avg       0.89      0.91      0.89      1030

# %%
plt.figure(figsize=(15,15))
plot_tree(dt1, class_names=cn, filled=True)
plt.show()
